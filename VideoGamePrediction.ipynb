# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("vgsales.csv")
print(data.head(10))
# Out:
#    Rank             Name Platform  Year     Genre   Publisher  NA_Sales  \
# 0   259        Asteroids     2600  1980   Shooter       Atari      4.00
# 1   545  Missile Command     2600  1980   Shooter       Atari      2.56
# 2  1768          Kaboom!     2600  1980      Misc  Activision      1.07
# 3  1971         Defender     2600  1980      Misc       Atari      0.99
# 4  2671           Boxing     2600  1980  Fighting  Activision      0.72
# 5  4027       Ice Hockey     2600  1980    Sports  Activision      0.46
# 6  5368          Freeway     2600  1980    Action  Activision      0.32
# 7  6319           Bridge     2600  1980      Misc  Activision      0.25
# 8  6898         Checkers     2600  1980      Misc       Atari      0.22
# 9   240         Pitfall!     2600  1981  Platform  Activision      4.21
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      0.26       0.0         0.05          4.31
# 1      0.17       0.0         0.03          2.76
# 2      0.07       0.0         0.01          1.15
# 3      0.05       0.0         0.01          1.05
# 4      0.04       0.0         0.01          0.77
# 5      0.03       0.0         0.01          0.49
# 6      0.02       0.0         0.00          0.34
# 7      0.02       0.0         0.00          0.27
# 8      0.01       0.0         0.00          0.24
# 9      0.24       0.0         0.05          4.50

# %%
print(data.isnull().sum())
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       36
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %%
data = data.dropna()

# %%
import matplotlib as mpl
game = data.groupby("Genre")["Global_Sales"].count().head(10)
custom_colors = mpl.colors.Normalize(vmin=min(game), vmax=max(game))
colours = [mpl.cm.PuBu(custom_colors(i)) for i in game]
plt.figure(figsize=(7,7))
plt.pie(game, labels=game.index, colors=colours)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 10 Categories of Games Sold", fontsize=20)
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr(), cmap="winter_r")
plt.show()
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.177655 -0.400317 -0.379143 -0.269326    -0.332739
# Year          0.177655  1.000000 -0.091233  0.006236 -0.169391     0.041248
# NA_Sales     -0.400317 -0.091233  1.000000  0.768919  0.451278     0.634513
# EU_Sales     -0.379143  0.006236  0.768919  1.000000  0.436373     0.726253
# JP_Sales     -0.269326 -0.169391  0.451278  0.436373  1.000000     0.290553
# Other_Sales  -0.332739  0.041248  0.634513  0.726253  0.290553     1.000000
# Global_Sales -0.426979 -0.074565  0.941268  0.903262  0.612770     0.747960
#
#               Global_Sales
# Rank             -0.426979
# Year             -0.074565
# NA_Sales          0.941268
# EU_Sales          0.903262
# JP_Sales          0.612770
# Other_Sales       0.747960
# Global_Sales      1.000000
# C:\Users\sarve\AppData\Local\Temp\ipykernel_1792\1329380345.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.corr())
# C:\Users\sarve\AppData\Local\Temp\ipykernel_1792\1329380345.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), cmap="winter_r")

# %%
x = data[["Rank", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]]
y = data["Global_Sales"]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
predictions = model.predict(xtest)
print(predictions)
# Out:
# [0.0705823  1.66975138 2.29967932 ... 1.48979017 0.06059278 1.32974684]

# %% [markdown]
# finding accuracy
